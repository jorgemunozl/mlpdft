# %% [markdown]
# <a href="https://colab.research.google.com/github/jorgemunozl/mlpdft/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/jorgemunozl/mlpdft.git
# Out:
# fatal: destination path 'mlpdft' already exists and is not an empty directory.

# %%
# %cd mlpdft
# Out:
# /content/mlpdft

# %%
# !uv sync
# Out:
# Using CPython 3.12.13 interpreter at: /usr/bin/python3
# Creating virtual environment at: .venv
# Resolved 71 packages in 20ms
# Prepared 60 packages in 11.03s
# Installed 60 packages in 384ms
#  + annotated-doc==0.0.4
#  + anyio==4.13.0
#  + ase==3.28.0
#  + certifi==2026.5.20
#  + click==8.4.1
#  + configargparse==1.7.5
#  + contourpy==1.3.3
#  + cycler==0.12.1
#  + e3nn==0.4.4
#  + filelock==3.29.0
#  + fonttools==4.62.1
#  + fsspec==2026.3.0
#  + gitdb==4.0.12
#  + gitpython==3.1.47
#  + h11==0.16.0
#  + h5py==3.16.0
#  + hf-xet==1.5.1
#  + httpcore==1.0.9
#  + httpx==0.28.1
#  + huggingface-hub==1.19.0
#  + idna==3.18
#  + jinja2==3.1.6
#  + kiwisolver==1.5.0
#  + lightning-utilities==0.15.3
#  + lmdb==2.2.0
#  + mace-torch==0.3.15
#  + markdown-it-py==4.2.0
#  + markupsafe==3.0.3
#  + matplotlib==3.10.9
#  + matscipy==1.2.0
#  + mdurl==0.1.2
#  + mpmath==1.3.0
#  + networkx==3.6.1
#  + numpy==2.4.4
#  + opt-einsum==3.4.0
#  + opt-einsum-fx==0.1.4
#  + orjson==3.11.8
#  + packaging==26.2
#  + pandas==3.0.2
#  + pillow==12.2.0
#  + prettytable==3.17.0
#  + pygments==2.20.0
#  + pyparsing==3.3.2
#  + python-dateutil==2.9.0.post0
#  + python-hostlist==2.3.0
#  + pyyaml==6.0.3
#  + rich==15.0.0
#  + scipy==1.17.1
#  + setuptools==81.0.0
#  + shellingham==1.5.4
#  + six==1.17.0
#  + smmap==5.0.3
#  + sympy==1.14.0
#  + torch==2.11.0+cpu
#  + torch-ema==0.3
#  + torchmetrics==1.9.0
#  + tqdm==4.67.3
#  + typer==0.25.1
#  + typing-extensions==4.15.0
#  + wcwidth==0.6.0

# %%
# !uv run pip install -e .
# Out:
# Obtaining file:///content/mlpdft
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: torch<3,>=2.2 in /usr/local/lib/python3.12/dist-packages (from mlpdft==0.0.0) (2.11.0+cu128)
# Requirement already satisfied: mace-torch>=0.3.6 in /usr/local/lib/python3.12/dist-packages (from mlpdft==0.0.0) (0.3.16)
# Requirement already satisfied: huggingface-hub>=1.19.0 in /usr/local/lib/python3.12/dist-packages (from mlpdft==0.0.0) (1.20.1)
# Requirement already satisfied: click>=8.4.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=1.19.0->mlpdft==0.0.0) (8.4.1)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=1.19.0->mlpdft==0.0.0) (3.29.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=1.19.0->mlpdft==0.0.0) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=1.19.0->mlpdft==0.0.0) (1.5.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=1.19.0->mlpdft==0.0.0) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=1.19.0->mlpdft==0.0.0) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=1.19.0->mlpdft==0.0.0) (6.0.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=1.19.0->mlpdft==0.0.0) (4.67.3)
# Requirement already satisfied: typer<0.26.0,>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=1.19.0->mlpdft==0.0.0) (0.25.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=1.19.0->mlpdft==0.0.0) (4.15.0)
# Requirement already satisfied: e3nn==0.4.4 in /usr/local/lib/python3.12/dist-packages (from mace-torch>=0.3.6->mlpdft==0.0.0) (0.4.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mace-torch>=0.3.6->mlpdft==0.0.0) (2.0.2)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.12/dist-packages (from mace-torch>=0.3.6->mlpdft==0.0.0) (3.4.0)
# Requirement already satisfied: ase in /usr/local/lib/python3.12/dist-packages (from mace-torch>=0.3.6->mlpdft==0.0.0) (3.28.0)
# Requirement already satisfied: torch-ema in /usr/local/lib/python3.12/dist-packages (from mace-torch>=0.3.6->mlpdft==0.0.0) (0.3)
# Requirement already satisfied: prettytable in /usr/local/lib/python3.12/dist-packages (from mace-torch>=0.3.6->mlpdft==0.0.0) (3.17.0)
# Requirement already satisfied: matscipy in /usr/local/lib/python3.12/dist-packages (from mace-torch>=0.3.6->mlpdft==0.0.0) (1.2.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (from mace-torch>=0.3.6->mlpdft==0.0.0) (3.16.0)
# Requirement already satisfied: torchmetrics in /usr/local/lib/python3.12/dist-packages (from mace-torch>=0.3.6->mlpdft==0.0.0) (1.9.0)
# Requirement already satisfied: python-hostlist in /usr/local/lib/python3.12/dist-packages (from mace-torch>=0.3.6->mlpdft==0.0.0) (2.3.0)
# Requirement already satisfied: configargparse in /usr/local/lib/python3.12/dist-packages (from mace-torch>=0.3.6->mlpdft==0.0.0) (1.7.5)
# Requirement already satisfied: GitPython in /usr/local/lib/python3.12/dist-packages (from mace-torch>=0.3.6->mlpdft==0.0.0) (3.1.50)
# Requirement already satisfied: lmdb in /usr/local/lib/python3.12/dist-packages (from mace-torch>=0.3.6->mlpdft==0.0.0) (2.2.1)
# Requirement already satisfied: orjson in /usr/local/lib/python3.12/dist-packages (from mace-torch>=0.3.6->mlpdft==0.0.0) (3.11.9)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mace-torch>=0.3.6->mlpdft==0.0.0) (3.10.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from mace-torch>=0.3.6->mlpdft==0.0.0) (2.2.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from e3nn==0.4.4->mace-torch>=0.3.6->mlpdft==0.0.0) (1.14.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from e3nn==0.4.4->mace-torch>=0.3.6->mlpdft==0.0.0) (1.16.3)
# Requirement already satisfied: opt-einsum-fx>=0.1.4 in /usr/local/lib/python3.12/dist-packages (from e3nn==0.4.4->mace-torch>=0.3.6->mlpdft==0.0.0) (0.1.4)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->mlpdft==0.0.0) (75.2.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->mlpdft==0.0.0) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->mlpdft==0.0.0) (3.1.6)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<3,>=2.2->mlpdft==0.0.0) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->mlpdft==0.0.0) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->mlpdft==0.0.0) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->mlpdft==0.0.0) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->mlpdft==0.0.0) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->mlpdft==0.0.0) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->mlpdft==0.0.0) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<3,>=2.2->mlpdft==0.0.0) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<3,>=2.2->mlpdft==0.0.0) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<3,>=2.2->mlpdft==0.0.0) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<3,>=2.2->mlpdft==0.0.0) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<3,>=2.2->mlpdft==0.0.0) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<3,>=2.2->mlpdft==0.0.0) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<3,>=2.2->mlpdft==0.0.0) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<3,>=2.2->mlpdft==0.0.0) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<3,>=2.2->mlpdft==0.0.0) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<3,>=2.2->mlpdft==0.0.0) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<3,>=2.2->mlpdft==0.0.0) (12.8.90)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings<13,>=12.9.4->torch<3,>=2.2->mlpdft==0.0.0) (1.5.5)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=1.19.0->mlpdft==0.0.0) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=1.19.0->mlpdft==0.0.0) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=1.19.0->mlpdft==0.0.0) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=1.19.0->mlpdft==0.0.0) (3.18)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=1.19.0->mlpdft==0.0.0) (0.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->e3nn==0.4.4->mace-torch>=0.3.6->mlpdft==0.0.0) (1.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.26.0,>=0.20.0->huggingface-hub>=1.19.0->mlpdft==0.0.0) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.26.0,>=0.20.0->huggingface-hub>=1.19.0->mlpdft==0.0.0) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer<0.26.0,>=0.20.0->huggingface-hub>=1.19.0->mlpdft==0.0.0) (0.0.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mace-torch>=0.3.6->mlpdft==0.0.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mace-torch>=0.3.6->mlpdft==0.0.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mace-torch>=0.3.6->mlpdft==0.0.0) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mace-torch>=0.3.6->mlpdft==0.0.0) (1.5.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mace-torch>=0.3.6->mlpdft==0.0.0) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mace-torch>=0.3.6->mlpdft==0.0.0) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mace-torch>=0.3.6->mlpdft==0.0.0) (2.9.0.post0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from GitPython->mace-torch>=0.3.6->mlpdft==0.0.0) (4.0.12)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<3,>=2.2->mlpdft==0.0.0) (3.0.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->mace-torch>=0.3.6->mlpdft==0.0.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->mace-torch>=0.3.6->mlpdft==0.0.0) (2026.2)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prettytable->mace-torch>=0.3.6->mlpdft==0.0.0) (0.8.1)
# Requirement already satisfied: lightning-utilities>=0.15.3 in /usr/local/lib/python3.12/dist-packages (from torchmetrics->mace-torch>=0.3.6->mlpdft==0.0.0) (0.15.3)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->GitPython->mace-torch>=0.3.6->mlpdft==0.0.0) (5.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mace-torch>=0.3.6->mlpdft==0.0.0) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub>=1.19.0->mlpdft==0.0.0) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub>=1.19.0->mlpdft==0.0.0) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub>=1.19.0->mlpdft==0.0.0) (0.1.2)
# Building wheels for collected packages: mlpdft
#   Building editable for mlpdft (pyproject.toml) ... done
#   Created wheel for mlpdft: filename=mlpdft-0.0.0-0.editable-py3-none-any.whl size=4216 sha256=1f386a90ddb0cce9fa25aa8f8cc4def8660566869f2ba870eaa593566d32b7ff
#   Stored in directory: /tmp/pip-ephem-wheel-cache-j872dnt8/wheels/9a/cd/3f/c27efafdffd2440894d7bfe6db85515d6f65e40a2de7b8601d
# Successfully built mlpdft
# Installing collected packages: mlpdft
#   Attempting uninstall: mlpdft
#     Found existing installation: mlpdft 0.0.0
#     Uninstalling mlpdft-0.0.0:
#       Successfully uninstalled mlpdft-0.0.0
# Successfully installed mlpdft-0.0.0

# %%
import os
import sys

os.environ['MPLBACKEND'] = 'Agg'

# Add the 'src' directory to PYTHONPATH for the subprocess
python_path = os.path.join(os.getcwd(), 'src')
os.environ['PYTHONPATH'] = python_path + os.pathsep + os.environ.get('PYTHONPATH', '')

print(f"PYTHONPATH set to: {os.environ['PYTHONPATH']}")

# !/content/mlpdft/.venv/bin/python src/mlpdft/train.py
# Out:
# PYTHONPATH set to: /content/mlpdft/src:/env/python
# /content/mlpdft/.venv/lib/python3.12/site-packages/e3nn/o3/_wigner.py:10: UserWarning: Environment variable TORCH_FORCE_NO_WEIGHTS_ONLY_LOAD detected, since the`weights_only` argument was not explicitly passed to `torch.load`, forcing weights_only=False.
#   _Jd, _W3j_flat, _W3j_indices = torch.load(os.path.join(os.path.dirname(__file__), 'constants.pt'))
# cuequivariance or cuequivariance_torch is not available. Cuequivariance acceleration will be disabled.
# minimal_li_f_mace_dataset.extxyz: 100% 51.9M/51.9M [00:04<00:00, 10.5MB/s]
# 2026-06-20 16:34:09.872 INFO: ===========VERIFYING SETTINGS===========
# 2026-06-20 16:34:09.872 INFO: Stage Two is activated as start_stage_two was defined
# 2026-06-20 16:34:09.872 WARNING: start_stage_two must be less than max_num_epochs, got 240 > 1
# 2026-06-20 16:34:09.872 WARNING: Stage Two will not start, as start_stage_two > max_num_epochs
# 2026-06-20 16:34:09.873 INFO: MACE version: 0.3.15
# 2026-06-20 16:34:09.873 INFO: Using CPU
# /content/mlpdft/.venv/lib/python3.12/site-packages/mace/cli/run_train.py:169: UserWarning: Environment variable TORCH_FORCE_NO_WEIGHTS_ONLY_LOAD detected, since the`weights_only` argument was not explicitly passed to `torch.load`, forcing weights_only=False.
#   model_foundation = torch.load(
# Traceback (most recent call last):
#   File "/content/mlpdft/src/mlpdft/train.py", line 132, in <module>
#     run(args)
#   File "/content/mlpdft/.venv/lib/python3.12/site-packages/mace/cli/run_train.py", line 169, in run
#     model_foundation = torch.load(
#                        ^^^^^^^^^^^
#   File "/content/mlpdft/.venv/lib/python3.12/site-packages/torch/serialization.py", line 1530, in load
#     with _open_file_like(f, "rb") as opened_file:
#          ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/mlpdft/.venv/lib/python3.12/site-packages/torch/serialization.py", line 795, in _open_file_like
#     return _open_file(name_or_buffer, mode)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/mlpdft/.venv/lib/python3.12/site-packages/torch/serialization.py", line 776, in __init__
#     super().__init__(open(name, mode))  # noqa: SIM115
#                      ^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: '/content/mlpdft/src/mlpdft/outputs/models/0-omat-medium/mace-omat-0-medium.model'
