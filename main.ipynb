# %% [markdown]
# <a href="https://colab.research.google.com/github/jorgemunozl/mlpdft/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/jorgemunozl/mlpdft.git
# Out:
# Cloning into 'mlpdft'...
# remote: Enumerating objects: 275, done.
# remote: Counting objects: 100% (181/181), done.
# remote: Compressing objects: 100% (118/118), done.
# remote: Total 275 (delta 81), reused 149 (delta 57), pack-reused 94 (from 1)
# Receiving objects: 100% (275/275), 51.52 MiB | 21.44 MiB/s, done.
# Resolving deltas: 100% (106/106), done.

# %%
# %cd mlpdft
# Out:
# /content/mlpdft

# %%
# !uv sync
# Out:
# Using CPython 3.12.13 interpreter at: /usr/bin/python3
# Creating virtual environment at: .venv
# Resolved 54 packages in 12ms
# ⠋ Preparing packages... (43/44)                                                 ^C

# %%
# !uv pip install -e .
# Out:
# Using Python 3.12.13 environment at: /usr
# Resolved 47 packages in 1.17s
# Prepared 2 packages in 1.55s
# Installed 12 packages in 154ms
#  + ase==3.28.0
#  + configargparse==1.7.5
#  + e3nn==0.4.4
#  + lightning-utilities==0.15.3
#  + lmdb==2.2.0
#  + mace-torch==0.3.16
#  + matscipy==1.2.0
#  + mlpdft==0.0.0 (from file:///content/mlpdft)
#  + opt-einsum-fx==0.1.4
#  + python-hostlist==2.3.0
#  + torch-ema==0.3
#  + torchmetrics==1.9.0

# %%
from mlpdft.constants import X
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_2628/381530655.py in <cell line: 0>()
# ----> 1 from mlpdft.constants import X
#
# ModuleNotFoundError: No module named 'mlpdft.constants'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
